# %% [markdown]
# # data frame with 4 features and observations

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame({'Name':['shanthi','priya','rohini','soni'],'english':[96,85,50,76],'hindi':[80,70,50,55],'Computer':[85,89,78,62],'science':[87,65,95,75]})
df
# Out:
#       Name  english  hindi  Computer  science
# 0  shanthi       96     80        85       87
# 1    priya       85     70        89       65
# 2   rohini       50     50        78       95
# 3     soni       76     55        62       75

# %% [markdown]
# # changing column names

# %%
df.columns =['Name','Random_value 1','Random_value 2','Random_value 3','Random_value 4']
df
# Out:
#       Name  Random_value 1  Random_value 2  Random_value 3  Random_value 4
# 0  shanthi              96              80              85              87
# 1    priya              85              70              89              65
# 2   rohini              50              50              78              95
# 3     soni              76              55              62              75

# %% [markdown]
# # descriptive statistics

# %%
df.describe()
# Out:
#        Random_value 1  Random_value 2  Random_value 3  Random_value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean        76.750000       63.750000       78.500000       80.500000
# std         19.619293       13.768926       11.902381       13.203535
# min         50.000000       50.000000       62.000000       65.000000
# 25%         69.500000       53.750000       74.000000       72.500000
# 50%         80.500000       62.500000       81.500000       81.000000
# 75%         87.750000       72.500000       86.000000       89.000000
# max         96.000000       80.000000       89.000000       95.000000

# %% [markdown]
# # null values

# %%
df.isnull().any()
# Out:
# Name              False
# Random_value 1    False
# Random_value 2    False
# Random_value 3    False
# Random_value 4    False
# dtype: bool

# %% [markdown]
# # data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      object
#  1   Random_value 1  4 non-null      int64
#  2   Random_value 2  4 non-null      int64
#  3   Random_value 3  4 non-null      int64
#  4   Random_value 4  4 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 288.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      object
#  1   Random_value 1  4 non-null      int64
#  2   Random_value 2  4 non-null      int64
#  3   Random_value 3  4 non-null      int64
#  4   Random_value 4  4 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 288.0+ bytes

# %% [markdown]
# # location and ilocation methods

# %%
df.iloc[:,2:4]
# Out:
#    Random_value 2  Random_value 3
# 0              80              85
# 1              70              89
# 2              50              78
# 3              55              62

# %%
df.loc[:,'Random_value 2':'Random_value 3']
# Out:
#    Random_value 2  Random_value 3
# 0              80              85
# 1              70              89
# 2              50              78
# 3              55              62
